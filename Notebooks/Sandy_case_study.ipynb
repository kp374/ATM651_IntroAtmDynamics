# %% [markdown]
# <a name="top"></a>
#
# <div style="width:1000 px">
#
# <div style="float:right; width:300 px"><img src="https://www.earthcube.org/sites/default/files/doc-repository/logo_earthcube_cube-only_SMALL.png" alt="EarthCube logo" style="height: 200px;"></div>
#
# <h1>Case study of Superstorm Sandy</h1>
#
# <h2>Selected Because of its Influence to my Career Path</h2>
#
# <br>
#
# <hr style="height:2px;">
#
# Compiled by: Karen Papazian
#
# <hr style="height:2px;">
#
#
# ### Sections within this notebook
# 1. <a href="#Anchor0">The story, with Web and journalism links</a>
# 1. <a href="#Anchor1">The meteorology: large-scale 2D flow evolution</a>
# 1. <a href="#Anchor3">The meteorology: analyses of 3D fields</a>
# 1. <a href="#Anchor2">The meteorology: clouds and rain, connection to soundings, etc.</a>
#
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">

# %% [markdown]
# <a name="Anchor0"></a>
# <div class="alert alert-success">
#     <b>**The story, with Web and journalism links**</b>:
#      <ul>
#
# <li>*Write a coherent narrative in your own words about the event, with links.*</li>
#
# <li>The goal is to make this document a professional portfolio item you're proud of</li>
#
# <li>Learn enough Markdown to make section headers, include URLs nicely, etc.</li>
#
# <li>You've done image inclusion before, Web-search or use an example from your repo</li>
#
# <li>Web-serach "Jupyter YouTube" for how to include video links</li>
#
#     </ul>
# </div>

# %% [markdown]
# <hr style="height:2px;">

# %% [markdown]
# <a name="Anchor1"></a>
# <div class="alert alert-success">
#     <b>**The meteorology, with IDV images**</b>:
#      <ul>
#
# <li>*Examine the 2D fields* and get a good understanding of your case.</li>
#
#
# <li>Extreme events (which is what we selected) always involve multiple factors coming together in rare ways. What are the ingredients or factors that came together in your case?</li>
#
# <li>Explain the 500mb evolution with vorticity (the 500mb GeoRelVort display).</li>
#
# <li>Illustrate your clear verbal description with images or short loops of crucial events or steps in the evolution.</li>
#
#     </ul>
# </div>

# %%
# %reload_ext drilsdown
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-06399fbebf41> in <module>
# ----> 1 get_ipython().run_line_magic('reload_ext', 'drilsdown')
#
# ~/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2312                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2313             with self.builtin_trap:
# -> 2314                 result = fn(*args, **kwargs)
#    2315             return result
#    2316
#
# </Users/karenpapazian/miniconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-66> in reload_ext(self, module_str)
#
# ~/miniconda3/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/miniconda3/lib/python3.7/site-packages/IPython/core/magics/extension.py in reload_ext(self, module_str)
#      61         if not module_str:
#      62             raise UsageError('Missing module name.')
# ---> 63         self.shell.extension_manager.reload_extension(module_str)
#
# ~/miniconda3/lib/python3.7/site-packages/IPython/core/extensions.py in reload_extension(self, module_str)
#     128                 self.loaded.add(module_str)
#     129         else:
# --> 130             self.load_extension(module_str)
#     131
#     132     def _call_load_ipython_extension(self, mod):
#
# ~/miniconda3/lib/python3.7/site-packages/IPython/core/extensions.py in load_extension(self, module_str)
#      78             if module_str not in sys.modules:
#      79                 with prepended_to_syspath(self.ipython_extension_dir):
# ---> 80                     mod = import_module(module_str)
#      81                     if mod.__file__.startswith(self.ipython_extension_dir):
#      82                         print(("Loading extensions from {dir} is deprecated. "
#
# ~/miniconda3/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~/miniconda3/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/miniconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/miniconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'drilsdown'

# %% [markdown]
# ### The 500 mb evolution of the event

# %%
# %make_image -caption 'rain_v850_w_section'

# %% [markdown]
# #### Caption:  xxx
#
# ### Meaning:
# The material above indicates that ...

# %%
# Moving image 
# %make_movie

# %% [markdown]
# #### Caption:  xxx
#
# ### Meaning:
# The material above indicates that ...

# %% [markdown]
# <hr style="height:2px;">
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Anchor2"></a>
# ## The meteorology: analyses of 3D fields

# %% [markdown]
# <div class="alert alert-info">
#     <b>Note</b>:
#      Load the 3D bundle, and use the 3D isosurface to understand the 3D strcture of the vortices you saw at 500 mb.
# </div>

# %%
# Unzip it so Python can then read its datafiles directly : why does this fail? 
# exec("unzip "+bundlefile)

# %% [markdown]
# ### Tell the story

# %%
# %make_image -caption 'rain_v850_w_section'

# %% [markdown]
# #### Caption:  xxx
#
# ### Meaning:
# The material above indicates that ...

# %%
# Moving image 
# %make_movie

# %% [markdown]
# #### Caption:  xxx
#
# ### Meaning:
# The material above indicates that ...

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Anchor3"></a>
# <div class="alert alert-success">
#     <b>Vorticity in 3D, the 500 mb height footprint, and clouds & precip</b>:
#      <ul>
#       <li>**Tell the story**
#            </li>
#     </ul>
# </div>

# %%
# %make_image -caption 'upper_and_lower_vortices_nearing_interaction'

# %% [markdown]
# #### Caption:  An upper trough and hurricane Sandy in Absolute Vorticity and Z500 fields
#
# ### Meaning:
# Flow induced by the vortices mutually advect the voricity of the other one

# %%
# Moving image 
# %make_movie

# %% [markdown]
# #### Caption:  xxx
#
# ### Meaning:
# The material above indicates that ...

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">
